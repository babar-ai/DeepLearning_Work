# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.5/983.5 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="r2n5cFtjLCiVJzGQ4G8h")
project = rf.workspace("test11-iml4z").project("gun3-rove6")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to gun3-2 in yolov5pytorch:: 100%|██████████| 17146/17146 [00:02<00:00, 8468.63it/s]

# %%
# %cd /content/gun3-2/
# print("/content/gun3-2/")
# Out:
# /content/gun3-2/

# %%
# to disply the directires inside the gun3-2
import os

yaml_data = """

names:
  - '1'
  - '2'
  - '3'
  - '4'
  - '5'
nc: 5
roboflow:
  license: CC BY 4.0
  project: gun3-rove6
  url: https://universe.roboflow.com/test11-iml4z/gun3-rove6/dataset/2
  version: 2
  workspace: test11-iml4z
train: /kaggle/working/gun3-2/train/images
val: /kaggle/working/gun3-2/valid/images
test: /kaggle/working/gun3-2/test/images




"""

with open('/kaggle/working/gun3-2/data.yaml', 'w') as f:
    f.write(yaml_data)

# %%
# to load pre_trained model YOLO_V8
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.train(data='/kaggle/working/gun3-2/data.yaml', epochs=30, imgsz=640, batch=16)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 183MB/s]
# Ultralytics 8.3.114 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO

# Load the best trained weights
model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# %%
model.predict(source='/kaggle/working/gun3-2/test/images', save=True, conf=0.25)
# Out:
# image 1/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_14_png_jpg.rf.db9e3f9be1070536f93d5816269bc276.jpg: 640x640 1 3, 6.2ms
# image 2/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_17_png_jpg.rf.44efc6ceff2a3f09ff06d264e28c4723.jpg: 640x640 2 3s, 5.7ms
# image 3/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_19_jpeg_jpg.rf.c588ceb5a1f1670bec3dd2570dfa5961.jpg: 640x640 1 3, 5.6ms
# image 4/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_20_jpeg_jpg.rf.06b237ef42d7d1ec9431414344b61224.jpg: 640x640 1 1, 6.1ms
# image 5/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_22_png_jpg.rf.29a2428ec559a36e82e41734f1031cab.jpg: 640x640 1 3, 5.8ms
# image 6/10 /kaggle/working/gun3-2/test/images/images-of-pistol-in-hand-transparent_25_jpeg_jpg.rf.e9fdd5ecb2d2d26963b19af9d68bf18b.jpg: 640x640 1 3, 5.7ms
# ...

# %%
import os
from IPython.display import Image, display

# Path where predictions are saved
pred_dir = 'runs/detect/predict'

# Show a few predicted images
pred_imgs = os.listdir(pred_dir)
for img_file in pred_imgs[:10]:  # Show first 3
    display(Image(filename=os.path.join(pred_dir, img_file)))

# %%
metrics = model.val()  # Uses val set from training config
print(metrics)
# Out:
# Ultralytics 8.3.114 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 901.2±499.7 MB/s, size: 37.2 KB)
# val: Scanning /kaggle/working/gun3-2/valid/labels.cache... 1689 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1689/1689 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 106/106 [00:11<00:00,  9.36it/s]
#                    all       1689       4379      0.822      0.606      0.661      0.391
#                      1       1077       1898      0.948      0.909      0.971      0.671
#                      2        913       1216          1          0      0.254      0.107
#                      3        692       1104      0.647      0.781      0.735      0.423
#                      4        131        152       0.74      0.562      0.626      0.386
# ...
